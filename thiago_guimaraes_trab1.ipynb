# %%
import pandas as pd
import numpy as np

# %%
arquivo = pd.read_excel("dados.xlsx")

# %%
arquivo.describe()
# Out:
#                       Titulo     Setor  ... Formato Numero de registros
# count                     48        48  ...      45                  17
# unique                    48        29  ...      12                  16
# top     TV Show informations  Diversos  ...     CSV          20 milhoes
# freq                       1         6  ...      14                   2
#
# [4 rows x 5 columns]

# %%
arquivo[arquivo['Setor'] == 'Tecnologia']
# Out:
#                                           Titulo  ... Numero de registros
# 0                               Google Data base  ...                 NaN
# 2  Microsoft Knowledge Base Articles on Database  ...                 NaN
# 9           Acesso a internet e posse de celular  ...                 378
#
# [3 rows x 5 columns]

# %%
arquivo.sort_values(by = 'Titulo')
# Out:
#                                              Titulo  ... Numero de registros
# 9              Acesso a internet e posse de celular  ...                 378
# 37                                             Anac  ...               137 k
# 14             AniList API V2 GraphQL Documentation  ...             500k ++
# 43                       Banco de Dados MyAnimeList  ...                 NaN
# 42                Banco de Dados jogadores FIFA 20   ...                 NaN
# 4                                          BuzzFeed  ...                 NaN
# 47  COVID-19 new cases and total cases per country.  ...                 NaN
# 25                                          Cartola  ...                 NaN
# 21                             Comercio no Exterior  ...               200K+
# 27           Consumo de bebidas alcoólicas no mundo  ...                 194
# 44                               Copa do Mundo 2018  ...                 NaN
# ...

# %% [markdown]
# Thiago Guimarães - 0050015244
